# %% [markdown]
# # Scraping reviews from Reclame Aqui website

# %% [markdown]
# ## Imports

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import math
#import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# ## Create driver

# %%
options = Options()
options.add_argument('--headless')
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(options=options)

# %% [markdown]
# ## Define Functions

# %%
def create_url(company, page):
    return f'https://www.reclameaqui.com.br/empresa/{company}/lista-reclamacoes/?pagina={page}'

# %%
def get_soup(driver,url):
    driver.get(url)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    time.sleep(1)
    soup = BeautifulSoup(driver.page_source, "html.parser")
    return soup

# %%
def get_complaints(soup):
    complaints = soup.find_all(class_="link-complain-id-complains")
    return complaints

# %%
def get_titles(complaints):
    title_list = []
    for i in range(len(complaints)):
        title_list.append(complaints[i].text.strip())
    return title_list

# %%
def get_links(complaints):
    link_list = []
    start_url = 'https://www.reclameaqui.com.br'
    for i in range(len(complaints)):
        link = (start_url + complaints[i].get('href'))
        link_list.append(link)
    return link_list

# %%
def get_content(soup):
    try:
        content = soup.find_all('p', class_="ng-binding")[9].text.strip()
        return content
    except:
        return 'NA'

# %%
def get_titles_and_links(company, num_pages, driver):
    titles = []
    links = []
    for i in range(1, num_pages+1):
        page_url = create_url(company, i)
        page_soup = get_soup(driver, page_url)
        page_complaints = get_complaints(page_soup)
        page_titles = get_titles(page_complaints)
        page_links = get_links(page_complaints)
        
        titles += page_titles
        links += page_links
        
    return titles, links

# %%
def get_content_list(driver, links):
    content_list = []
    for i in range(len(links)):
        url = links[i]
        soup = get_soup(driver,url)
        print(f'Retrieved {i+1} of {len(links)}')
        content = get_content(soup)
        content_list.append(content)
    return content_list

# %% [markdown]
# ## Test Functions

# %%
titles, links = get_titles_and_links('upnid',1,driver)

# %%
titles
# Out:
# []

# %%
links
# Out:
# ['https://www.reclameaqui.com.br/upnid/comprei-e-nao-recebi_DLMdwWwuv0C85DcZ/',
#  'https://www.reclameaqui.com.br/upnid/nao-compre-na-flipcart_M6c3cnBwGvE8RNmP/',
#  'https://www.reclameaqui.com.br/upnid/comprei-nao-recebi_wn7QFAzRBJO2pwup/',
#  'https://www.reclameaqui.com.br/upnid/cobranca-indevida_lqWsHt97_dkZeBNF/',
#  'https://www.reclameaqui.com.br/upnid/produto-nao-entregue_PJfWvuC7cvdc4LuM/',
#  'https://www.reclameaqui.com.br/upnid/fiz-uma-compra-na-upnid-em-26-01-2021-e-ate-o-momento-nao-recebi-o-produto_DHLCzGSQ4hRdC2po/',
#  'https://www.reclameaqui.com.br/upnid/empresa-nao-idonea_G2ZA0-zJIJgCRli7/',
#  'https://www.reclameaqui.com.br/upnid/upnid-tv-global_7YmhsMES98qHeKfa/',
#  'https://www.reclameaqui.com.br/upnid/produto-nao-recebido_IVUyV4L-uOJlnDim/',
#  'https://www.reclameaqui.com.br/upnid/titulo_PelzEXcDwMywOdRF/',
#  'https://www.reclameaqui.com.br/upnid/site-shopmakee-nao-aparece-mais_ZCQCbWAfaWGCRHEI/',
#  'https://www.reclameaqui.com.br/upnid/comprei-um-kit-de-alongamento-e-ainda-nao-enviaram_rNOlHUMMhnjoJZ55/',
#  'https://www.reclameaqui.com.br/upnid/compra-sem-confirmacao-por-e-mail_02uYTGiVZrw6m2j8/',
#  'https://www.reclameaqui.com.br/upnid/compra-sem-retorno_8S7y0uPl-xtVztJc/',
#  'https://www.reclameaqui.com.br/upnid/modelador-aluvi-airwrap-5-em-1-1_nBOsoPXOHWfNHHll/',
#  'https://www.reclameaqui.com.br/upnid/produto-nao-entregue_ROOh8Dv36k2GZMy2/',
#  'https://www.reclameaqui.com.br/upnid/comprei-e-nao-recebi_Yu3dwgC7JUEsG4T9/',
#  'https://www.reclameaqui.com.br/upnid/nao-recebi-o-produto_08dtax5MJuIRP75O/',
#  'https://www.reclameaqui.com.br/upnid/compra-tv-global_6fe6i3TBUozMqFED/',
#  'https://www.reclameaqui.com.br/upnid/faggio-store_L-T5i0Nd-r7rgJay/']

# %%
contents = get_content_list(driver,links)
# Out:
# <html class="ng-scope" lang="pt-BR" ng-app="rawebApp"><head><style type="text/css">[uib-typeahead-popup].dropdown-menu{display:block;}</style><style type="text/css">.uib-time input{width:50px;}</style><style type="text/css">[uib-tooltip-popup].tooltip.top-left > .tooltip-arrow,[uib-tooltip-popup].tooltip.top-right > .tooltip-arrow,[uib-tooltip-popup].tooltip.bottom-left > .tooltip-arrow,[uib-tooltip-popup].tooltip.bottom-right > .tooltip-arrow,[uib-tooltip-popup].tooltip.left-top > .tooltip-arrow,[uib-tooltip-popup].tooltip.left-bottom > .tooltip-arrow,[uib-tooltip-popup].tooltip.right-top > .tooltip-arrow,[uib-tooltip-popup].tooltip.right-bottom > .tooltip-arrow,[uib-tooltip-html-popup].tooltip.top-left > .tooltip-arrow,[uib-tooltip-html-popup].tooltip.top-right > .tooltip-arrow,[uib-tooltip-html-popup].tooltip.bottom-left > .tooltip-arrow,[uib-tooltip-html-popup].tooltip.bottom-right > .tooltip-arrow,[uib-tooltip-html-popup].tooltip.left-top > .tooltip-arrow,[uib-tooltip-html-popup].tooltip.left-bottom > .tooltip-arrow,[uib-tooltip-html-popup].tooltip.right-top > .tooltip-arrow,[uib-tooltip-html-popup].tooltip.right-bottom > .tooltip-arrow,[uib-tooltip-template-popup].tooltip.top-left > .tooltip-arrow,[uib-tooltip-template-popup].tooltip.top-right > .tooltip-arrow,[uib-tooltip-template-popup].tooltip.bottom-left > .tooltip-arrow,[uib-tooltip-template-popup].tooltip.bottom-right > .tooltip-arrow,[uib-tooltip-template-popup].tooltip.left-top > .tooltip-arrow,[uib-tooltip-template-popup].tooltip.left-bottom > .tooltip-arrow,[uib-tooltip-template-popup].tooltip.right-top > .tooltip-arrow,[uib-tooltip-template-popup].tooltip.right-bottom > .tooltip-arrow,[uib-popover-popup].popover.top-left > .arrow,[uib-popover-popup].popover.top-right > .arrow,[uib-popover-popup].popover.bottom-left > .arrow,[uib-popover-popup].popover.bottom-right > .arrow,[uib-popover-popup].popover.left-top > .arrow,[uib-popover-popup].popover.left-bottom > .arrow,[uib-popover-popup].popover.right-top > .arrow,[uib-popover-popup].popover.right-bottom > .arrow,[uib-popover-html-popup].popover.top-left > .arrow,[uib-popover-html-popup].popover.top-right > .arrow,[uib-popover-html-popup].popover.bottom-left > .arrow,[uib-popover-html-popup].popover.bottom-right > .arrow,[uib-popover-html-popup].popover.left-top > .arrow,[uib-popover-html-popup].popover.left-bottom > .arrow,[uib-popover-html-popup].popover.right-top > .arrow,[uib-popover-html-popup].popover.right-bottom > .arrow,[uib-popover-template-popup].popover.top-left > .arrow,[uib-popover-template-popup].popover.top-right > .arrow,[uib-popover-template-popup].popover.bottom-left > .arrow,[uib-popover-template-popup].popover.bottom-right > .arrow,[uib-popover-template-popup].popover.left-top > .arrow,[uib-popover-template-popup].popover.left-bottom > .arrow,[uib-popover-template-popup].popover.right-top > .arrow,[uib-popover-template-popup].popover.right-bottom > .arrow{top:auto;bottom:auto;left:auto;right:auto;margin:0;}[uib-popover-popup].popover,[uib-popover-html-popup].popover,[uib-popover-template-popup].popover{display:block !important;}</style><style type="text/css">.uib-datepicker-popup.dropdown-menu{display:block;float:none;margin:0;}.uib-button-bar{padding:10px 9px 2px;}</style><style type="text/css">.uib-position-measure{display:block !important;visibility:hidden !important;position:absolute !important;top:-9999px !important;left:-9999px !important;}.uib-position-scrollbar-measure{position:absolute !important;top:-9999px !important;width:50px !important;height:50px !important;overflow:scroll !important;}.uib-position-body-scrollbar-measure{overflow:scroll !important;}</style><style type="text/css">.uib-datepicker .uib-title{width:100%;}.uib-day button,.uib-month button,.uib-year button{min-width:100%;}.uib-left,.uib-right{width:100%}</style><style type="text/css">.ng-animate.item:not(.left):not(.right){-webkit-transition:0s ease-in-out left;transition:0s ease-in-out left}</style><style type="tex ...
#
#                     googletag.enableServices();
#         });</script> <!-- Google Tag Manager --> <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-WDTCCZ9');</script> <!-- End Google Tag Manager --> <!-- GA snippet --> <script async="" type="text/javascript">(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#       ga('create', 'UA-5435672-2', 'auto');
#       ga('require', 'GTM-P97XK6B');
#       // ga('send', 'pageview');</script> <!-- END GA snippet --> <script async="" defer="" src="https://maps.googleapis.com/maps/api/js?libraries=places&amp;language=pt-BR&amp;key=AIzaSyD4Lk8WN2ABfBGRsNh6eQWQhAFyKPgbIT0"></script> <style>.ag-no-transition{-webkit-transition: none !important;transition: none !important;} .angular-grid{position : relative;} .angular-grid > *{opacity : 0} .angular-grid > .angular-grid-item{opacity : 1}</style><style></style><script async="" src="https://static.hotjar.com/c/hotjar-417945.js?sv=6"></script><style>#company-data-wrapper {top: 138px!important;} #company-statistics-mobile {top: 92px!important;} #menu-and-help {top: 114px!important;} #menu-mobile-modal {z-index: 10003!important;} #overlay-new-search {top: 141px!important;} @media (max-width:768px) {#overlay-new-search {top: 60px!important;}} @media (max-width:768px) {#overlay-new-search-fixed-nav {top: 60px!important;}} @media (max-width:768px) {#brand-page-header .brand-page-info .company-statistics.mobile #link-complain-mobile {margin: 0;}} @media (max-width:768px) {#brand-page-controller.compact-mobile .brand-page-info .company-statistics.mobile #link-complain-mobile {margin: 0;}} #header-inner-pages {top: 60px!important;} @media (max-width:768px) {#header-inner-pages {top: 0!important;}} @media (max-width:768px) {body .modal-backdrop {display: none;}} body .modal-backdrop {z-index: 10040} body .modal {z-index: 10050}</style><script src="https://trk.reclameaqui.com.br/assets/trk.min.js?trackIdRA=110983"></script><style data-fbcssmodules="css:fb.css.basecss:fb.css.dialog css:fb.css.iframewidget" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:transpar ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}</style></head> <body style="position: relative; overflow: auto; top: 0px; padding-top: 60px;"> <!--[if IE]>
#       <p class="browsehappy">O seu navegador está desatualizado! Por favor <a href="http://browsehappy.com/">instale uma versão atualizada</a> e tenha acesso a todas as funcionalidades do Reclame AQUI.</p>
#     <![endif]--> <div class="fb_reset" id="fb-root"><div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div></div></div></div> <!-- uiView: --><ui-view class="ng-scope"><!-- ngInclude: 'views/partials/nav.html' --><div class="header-fixed ng-scope" ng-include="'views/partials/nav.html'"><!-- Submenu desktop --> <stick-touchpoint class="ng-scope"><!-- ngIf: isStickBarEnabled --><div class="touchpoint-stick-wrapper ng-scope" id="stickbar-touchpoint" ng-click="stickBarClick()" ng-if="isStickBarEnabled"> <div class="touchpoint-stick-container"> <div class="stick-logo"> <img alt="Confie AQUI" src="https://storage.googleapis.com/reclameaqui-assets/images/confieaqui/confieaqui-logo.svg"/> </div> <img alt="Confie AQUI" class="stick-logo-bg" src="https://storage.googleapis.com/reclameaqui-assets/images/confieaqui/confieaqui-logo-bg.svg"/> <div class="stick-description"> <strong>Confiança e descontos reais</strong>, verificados pelo Reclame AQUI </div> <div class="touchpoint-stick-btn stick-btn ng-binding ng-isolate-scope orange" color="orange" ng-class="{ orange: (color==='orange'), green: (color==='green')}" ng-click="handleClick()" text="Clique AQUI">Clique AQUI</div> </div> </div><!-- end ngIf: isStickBarEnabled --> </stick-touchpoint> <modal-touchpoint class="ng-scope"><div> <!-- ngIf: showModal --> <!-- ngIf: showModal --> </div></modal-touchpoint> <div class="0 nav-up" id="header-inner-pages" ng-class="{'complain-flow': page.isComplainFlow() == true}" ng-controller="HeaderCtrl as head"> <div class="search-bar"> <div class="container"> <div class="header-inner-top"> <div class="row"> <div class="col-md-3 col-sm-3 col-xs-2 hidden-xs col-lg-2" ng-class="checkName === true ? 'col-lg-1' : 'col-lg-2'"> <div class="brand-logo"> <a class="hidden-xs" href="/" target="_self"><img ng-src="../images/reclame-aqui-logo.8cfb52a1.svg" src="../images/reclame-aqui-logo.8cfb52a1.svg"/></a> </div> <div class="logo-scroll"> <a class="hidden-xs" href="/" target="_self"><img src="../../images/raprime/logo-raprime-1.c47dba16.png"/></a> </div> </div> <div class="col-md-6 col-sm-6 col-xs-12 col-lg-8" ng-class="checkName === true ? 'col-lg-9' : 'col-lg-8'"> <div class="menu-inner-header hidden-lg hidden-md hidden-sm"> <ul class="list-inline" style="float: left"> <li class="hidden-xs"><!-- ngInclude: 'views/partials/category-menu.html' --><div class="ng-scope" ng-include="'views/partials/category-menu.html'"><div class="dropdown category-menu ng-scope" ng-controller="MainCtrl as main"> <a aria-expanded="false" aria-haspopup="true" class="dropdown-trigger" data-target="#" data-toggle="dropdown" role="button" title="Categorias do site"> Categorias <i class="fa fa-caret-down"></i> </a> <ul class="dropdown-menu dropdown-columns"> <div class="column-first"> <ul class="list-unstyled"> <li class="medium-title">Categorias</li> <li class="view-details-ecommerce hover-column-first"><a href="/ecommerce/" ng-mouseover="main.getCategoryRanking('0000000000000058')" title="Ecommerce">Ecommerce</a></li> <li class="view-details-turismo hover-column-first"><a href="/turismo-e-lazer/" ng-mouseover="main.getCategoryRanking('0000000000000017')" title="Turismo e Lazer">Turismo e Lazer</a></li> <li class="view-details-alimentos-e-bebidas hover-column-first"><a href="/alimentos-e-bebidas/" ng-mouseover="main.getCategoryRanking('0000000000000072')" title="Alimentos e Bebidas">Alimentos e Bebidas</a></li> <li class="view-details-bancos-e-cartoes hover-column-first"><a href="/bancos-e-cartoes/" ng-mouseover="main.getCategoryRanking('0000000000000121')" title="Bancos e Cartões">Bancos e Cartões</a></li> <li class="view-details-beleza-e-estetica hover-column-first"><a href="/beleza-e-estetica/" ng-mouseover="main.getCategoryRanking('0000000000000271')" title="Beleza e Estética">Beleza e Estética</a></li> <li class="view-details-casa-e-construcao hover-column-first"><a href="/casa-e-construcao/" ng-mouseover="main.getCategoryRanking('0000000000000185')" title="Casa ...
# 		if (window.matchMedia("(min-width: 992px)").matches) {
# 		  	$('.view-details-ecommerce').mouseenter(function(){
# 				$('.column-second-ecommerce, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-ecommerce, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-turismo').mouseenter(function(){
# 				$('.column-second-turismo, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-turismo, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-alimentos-e-bebidas').mouseenter(function(){
# 				$('.column-second-alimentos-e-bebidas, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-alimentos-e-bebidas, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-beleza-e-estetica').mouseenter(function(){
# 				$('.column-second-beleza-e-estetica, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-beleza-e-estetica, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao,  .column-second-casa-e-construcao, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-casa-e-construcao').mouseenter(function(){
# 				$('.column-second-casa-e-construcao, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-casa-e-construcao, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-educacao').mouseenter(function(){
# 				$('.column-second-educacao, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-educacao, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-bancos-e-cartoes').mouseenter(function(){
# 				$('.column-second-bancos-e-cartoes, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-bancos-e-cartoes, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-mae-e-bebe').mouseenter(function(){
# 				$('.column-second-mae-e-bebe, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-mae-e-bebe, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-moda').mouseenter(function(){
# 				$('.column-second-moda, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-moda, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-moveis-decoracao').mouseenter(function(){
# 				$('.column-second-moveis-decoracao, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-moveis-decoracao, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-saude').mouseenter(function(){
# 				$('.column-second-saude, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-saude, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-telefonia-tv-e-internet').mouseenter(function(){
# 				$('.column-second-telefonia-tv-e-internet, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-telefonia-tv-e-internet, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-veiculos-e-acessorios').mouseenter(function(){
# 				$('.column-second-veiculos-e-acessorios, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-veiculos-e-acessorios, .column-third-ranking').addClass('show');
# 				$('.column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-category').mouseenter(function(){
# 				$('.column-second-ranking, .column-third-image').removeClass('hidden');
# 				$('.column-second-ranking, .column-third-image').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-third-ranking').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios,  .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-third-ranking').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.dropdown-columns').mouseleave(function(){
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image, .column-third-ranking').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image, .column-third-ranking').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "250px");
# 			});
# 		}
# 	});
#
# 	$('.hover-column-first').on("mouseenter", function(){
# 		$('.hover-column-first').css('background-color','white');
# 		$(this).css('background-color','#ededed');
# 	});
#
# 	$('.hover-column-second').on("mouseenter", function(){
# 		$('.hover-column-second').css('background-color','white');
# 		$(this).css('background-color','#ededed');
# 	});
#
#
# 	$('.dropdown-menu').on("mouseleave", function(){
# 		$('.hover-column-first, .hover-column-second').css('background-color','white');
# 	}); </script> </div></li> <li class="hidden-xs"><a href="/compare/" title="Compare reputação de empresas">Compare</a></li> <li class="hidden-xs"><a href="/ranking/" title="Rankings de reclamações">Rankings</a></li> <li class="hidden-xs" ng-show="head.userType != 'Empresa'"><a href="/minha-conta/nova-compra" title="Cadastre suas compras">Cadastre sua compra</a></li> <li class="hidden-xs hidden-sm"><a href="/como-funciona/" title="Como funciona o ReclameAQUI" ui-sref="faq.main">Dúvidas frequentes</a></li> <li class="hidden-xs"><a href="/institucional/" target="_self" title="Sobre o ReclameAQUI">Institucional</a></li> <li class="hidden-xs hidden-sm"><a href="/categoria/" title="Explore todas as categorias">Todas as categorias</a></li> </ul> <div class="list-signin-signup"> <ul class="list-inline hidden-sm"> <li class="hidden-md hidden-lg"> <!-- ngIf: !showCloseArrow --><a class="ng-scope" data-target="#menu-mobile-modal" data-toggle="modal" ng-if="!showCloseArrow"> <span class="mdi mdi-24px mdi-menu"></span> </a><!-- end ngIf: !showCloseArrow --> <!-- ngIf: showCloseArrow --> </li> </ul> <div class="brand-logo hidden-lg hidden-md hidden-sm"> <a class="visible-xs" href="/" target="_self"><img alt="ReclameAQUI" ng-src="../images/reclame-aqui-logo-minify.baa6452e.png" src="../images/reclame-aqui-logo-minify.baa6452e.png" title="ReclameAqui"/></a> <a class="hidden-xs" href="/" target="_self"><img alt="ReclameAQUI" ng-src="../images/reclame-aqui-logo-minify.baa6452e.png" src="../images/reclame-aqui-logo-minify.baa6452e.png" title="ReclameAqui"/></a> </div> <div class="hidden-md hidden-lg list-inline"> <ul class="list-inline"> <li class="hidden-sm hidden-md hidden-lg"> <button class="btn-open-search" ng-click="head.makeVisible()"><span class="mdi mdi-24px mdi-magnify"></span></button> </li> <li class="hidden-xs"> <a analytics-category="1.0 Button: Entrar - Header - DF - Desktop" analytics-event="Clique" analytics-label="Entrar" analytics-on="click" class="btn-signin-list" ng-click="head.login()">Entrar </a> </li> </ul> </div> </div> </div> <!-- ngIf: !page.isComplainFlow() --><div class="scroll-control-header ng-scope" ng-class="{'hide-search': page.name === true}" ng-if="!page.isComplainFlow()"> <!-- ngInclude: 'views/partials/search-bar.html' --><div class="ng-scope" ng-include="'views/partials/search-bar.html'"><div class="ng-scope" ng-controller="searchDirectiveCtrl"> <div class="input-group hidden-xs" ng-init="shadow = false"> <div class="input-group search-btn-page" ng-class="{'shadow-box': shadow === true}"> <a ng-click="forComplain(head.searchTerm)"> <span class="input-group-btn mb-5 bg-white rounded"> <button class="btn btn-default" type="button"> <span class="mdi mdi-18px mdi-magnify"></span> </button> </span> </a> <input class="form-control input-auto-complete-search ng-pristine ng-untouched ng-valid ng-empty" ng-blur="shadow = false" ng-change="head.startSearch()" ng-focus="shadow = true" ng-keydown="($event.which === 13)?forComplain(head.searchTerm):0" ng-model="head.searchTerm" ng-model-options="{debounce: 600}" placeholder="O que você está procurando?" type="text"/> <span class="input-group-addon complain" id="basic-addon2" ng-click="complainChange(head.searchTerm)"> <em class="mdi mdi-18px mdi-bullhorn-outline"></em> Reclamar </span> </div> </div> <!-- ngIf: head.isVisible --> </div></div> </div><!-- end ngIf: !page.isComplainFlow() --> </div> <!-- UserOptions Desktop --> <div class="col-lg-2 col-md-2 col-sm-3 hidden-xs"> <!-- ngIf: !head.logado --><div class="btns-signin-signup ng-scope" ng-if="!head.logado"> <a analytics-category="1.0 Button: Entrar - Header - DF - Desktop" analytics-event="Clique" analytics-label="Entrar" analytics-on="click" class="btn-signin" id="btn-signIn-header" ng-click="head.login()"><span class="mdi mdi-24px mdi-account"></span><span class="account-text"> Entrar</span></a> </div><!-- end ngIf: !head.logado --> <!-- ngIf: head.logado --> </div> <div style="clear:both"></div> </div> </div> </d ...
# 		if (window.matchMedia("(min-width: 992px)").matches) {
# 		  	$('.view-details-ecommerce').mouseenter(function(){
# 				$('.column-second-ecommerce, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-ecommerce, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-turismo').mouseenter(function(){
# 				$('.column-second-turismo, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-turismo, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-alimentos-e-bebidas').mouseenter(function(){
# 				$('.column-second-alimentos-e-bebidas, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-alimentos-e-bebidas, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-beleza-e-estetica').mouseenter(function(){
# 				$('.column-second-beleza-e-estetica, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-beleza-e-estetica, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao,  .column-second-casa-e-construcao, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-casa-e-construcao').mouseenter(function(){
# 				$('.column-second-casa-e-construcao, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-casa-e-construcao, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-educacao').mouseenter(function(){
# 				$('.column-second-educacao, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-educacao, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-bancos-e-cartoes').mouseenter(function(){
# 				$('.column-second-bancos-e-cartoes, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-bancos-e-cartoes, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-mae-e-bebe, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-mae-e-bebe').mouseenter(function(){
# 				$('.column-second-mae-e-bebe, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-mae-e-bebe, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-moda, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').addClass('hidden');
# 				$('.dropdown-columns').css("min-width", "800px");
# 			});
# 			$('.view-details-moda').mouseenter(function(){
# 				$('.column-second-moda, .column-third-ranking').removeClass('hidden');
# 				$('.column-second-moda, .column-third-ranking').addClass('show');
# 				$('.column-second-veiculos-e-acessorios, .column-second-telefonia-tv-e-internet, .column-second-saude, .column-second-moveis-decoracao, .column-second-mae-e-bebe, .column-second-bancos-e-cartoes, .column-second-educacao, .column-second-casa-e-construcao, .column-second-beleza-e-estetica, .column-second-alimentos-e-bebidas, .column-second-turismo, .column-second-ecommerce, .column-second-ranking, .column-third-image').removeClass('show');
# ...
#     $('#modal-collect-suport').modal('hide');
#   }) </script> </div> <!-- ngInclude: 'views/partials/modal-collect-erro.html' --><div class="ng-scope" ng-include="'views/partials/modal-collect-erro.html'"><div class="ng-scope" id="modal-notifications-mobile"> <div class="modal fade" id="modal-collect-erro" role="dialog" tabindex="-1"> <div class="modal-dialog-collect" role="document"> <div class="modal-collect-erro"> <div class="modal-body text-center"> <button class="btn btn-link-collect closeModal"> <i class="fa fa-close"></i> </button> <img alt="" class="ervilho-sad" src="../../images/icons/sad-ervilho.ad5b4aff.png"/> <p class="primary-text">Ops, desculpe… </p> <p class="secondary-text"> Infelizmente algo de errado aconteceu, tente novamente ou entre em contato conosco. </p> <a class="raichu button button-blue size-default closeModal" href="/contato/" title="Entrar em contato" ui-sref="contact"> Entrar em contato </a> </div> </div> </div> </div> </div> <script class="ng-scope"> $('.closeModal').click(function() {
#     $('#modal-collect-erro').modal('hide');
#   }) </script> </div> <!-- <div ng-include ="'views/partials/modals-popbounce.html'"></div> --> <script src="scripts/vendor.fdd9743c.js"></script><div class="lightboxOverlay" id="lightboxOverlay" style="display: none;"></div><div class="lightbox" id="lightbox" style="display: none;"><div class="lb-outerContainer"><div class="lb-container"><img class="lb-image" src="..."/><div class="lb-nav"><a class="lb-prev" href=""></a><a class="lb-next" href=""></a></div><div class="lb-loader"><a class="lb-cancel"></a></div></div></div><div class="lb-dataContainer"><div class="lb-data"><div class="lb-details"><span class="lb-caption"></span><span class="lb-number"></span></div><div class="lb-closeContainer"><a class="lb-close"></a></div></div></div></div> <script src="scripts/scripts.82d38a9f.js"></script> <!-- Google Tag Manager (noscript) --> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WDTCCZ9" style="display:none;visibility:hidden" width="0"></iframe></noscript> <!-- End Google Tag Manager (noscript) --> <script type="text/javascript">var _ttraqui = _ttraqui || [];</script> <script async="" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&amp;ns=21&amp;cb=851332545" type="text/javascript"></script>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js?onload=vcRecaptchaApiLoaded&amp;render=explicit"></script><iframe src="https://auth.reclameaqui.com.br/auth/realms/reclameaqui/protocol/openid-connect/login-status-iframe.html" style="display: none;"></iframe><div style="display: none; visibility: hidden;"><script charset="UTF-8" data-document-language="true" data-domain-script="d82b2d0d-ccc2-44ef-acd6-2ecb6405b7b2" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script></div>
# <script id="" type="text/javascript">_atrk_opts={atrk_acct:"NleCg1asOv00oF",domain:"reclameaqui.com.br",dynamic:!0};(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://certify-js.alexametrics.com/atrk.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script>
# <noscript><img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=NleCg1asOv00oF" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">(function(a,c,e,f,d,b){a.hj=a.hj||function(){(a.hj.q=a.hj.q||[]).push(arguments)};a._hjSettings={hjid:417945,hjsv:6};d=c.getElementsByTagName("head")[0];b=c.createElement("script");b.async=1;b.src=e+a._hjSettings.hjid+f+a._hjSettings.hjsv;d.appendChild(b)})(window,document,"https://static.hotjar.com/c/hotjar-",".js?sv\x3d");</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","602950267007939");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=602950267007939&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">var testeABConfie=Math.floor(2*Math.random());
# 768>=window.innerWidth?(null!=document.querySelector(".stick-description")&&(document.querySelector(".stick-description").style.fontWeight="700"),null!=document.querySelector(".stick-btn.orange")&&(document.querySelector(".stick-btn.orange").innerHTML="Baixe o APP"),null!=document.querySelector(".stick-btn")&&(document.querySelector(".stick-btn").innerHTML="Baixe o APP")):null!=document.querySelector("#stickbar-touchpoint \x3e div")&&(document.querySelector("#stickbar-touchpoint \x3e div").style.width="900px");
# null!=document.querySelector("#stickbar-touchpoint \x3e div \x3e div.stick-description")&&(document.querySelector("#stickbar-touchpoint \x3e div \x3e div.stick-description").innerHTML="\x3cstrong\x3eConfian\u00e7a e descontos reais,\x3c/strong\x3e verificados pelo Reclame AQUI");</script><script id="" type="text/javascript">setTimeout(function(){var a=!1;void 0!=$("#link-complain").html()&&(a=$("#link-complain").attr("href").split("/")[2]);void 0!=$("#link-complain-left").html()&&(a=$("#link-complain-left").attr("href").split("/")[2]);void 0!=$("#link-complain-mobile").html()&&(a=$("#link-complain-mobile").attr("href").split("/")[2]);void 0!=$(".company-actions \x3e .btn-red").html()&&(a=$(".company-actions \x3e .btn-red").attr("href").split("/")[2]);for(var b=$("#trackRA").html();void 0!=b;)$("#trackRA").remove(),b=
# $("#trackRA").html();$("body").append("\x3cscript async id\x3d'trackRA' src\x3d'https://trk.reclameaqui.com.br/assets/trk.min.js?trackIdRA\x3d"+a+"\x26v\x3d1'\x3e\x3c/script\x3e")},1E3);</script>
# <script id="" type="text/javascript">setTimeout(function(){null!=document.querySelector(".jub-container")&&document.querySelector(".jub-container").remove()},2E3);</script><script id="" type="text/javascript">var dataReclamacao=$("div#complain-detail ul.local-date.list-inline \x3e li:nth-child(3)").text();dataReclamacao=dataReclamacao.split("/");var mes=dataReclamacao[1],ano=dataReclamacao[2].split(" ");ano=ano[0];if(18>=parseInt(ano)||19==parseInt(ano)&&7>=parseInt(mes))dataLayer.push({event:"optimize.reclamacao1ano"}),setTimeout(function(){hj("trigger","reclamacao_antiga")},3E3);</script><script id="" type="text/javascript">setTimeout(function(){void 0!=$("#header-inner-pages #header-inner-menu .container \x3e ul").html()&&0>$("#header-inner-pages #header-inner-menu .container \x3e ul").html().indexOf("Not\u00edcias")&&$("#header-inner-pages #header-inner-menu .container \x3e ul").append('\x3cli class\x3d"hidden-xs"\x3e\x3ca href\x3d"https://noticias.reclameaqui.com.br/" target\x3d"_blank" title\x3d"ReclameAqui Not\u00edcias" class\x3d""\x3eNot\u00edcias\x3c/a\x3e\x3c/li\x3e');void 0!=$("#menu-mobile-modal .menu-complete \x3e ul").html()&&
# (0>$("#menu-mobile-modal .menu-complete \x3e ul").html().indexOf("Pr\u00eamio")&&$("#menu-mobile-modal .menu-complete \x3e ul").append('\x3cli class\x3d"item" ui-sref-active\x3d"active"\x3e \x3ca  href\x3d"https://premio.reclameaqui.com.br/" target\x3d"_blank"\x3e \x3cspan class\x3d"item-icon"\x3e \x3ci class\x3d"mdi mdi-trophy-award" aria-hidden\x3d"true"\x3e\x3c/i\x3e \x3c/span\x3e \x3cem\x3ePr\u00eamio\x3c/em\x3e \x3ci class\x3d"fa fa-angle-right pull-right"\x3e\x3c/i\x3e \x3c/a\x3e \x3c/li\x3e'),
# 0>$("#menu-mobile-modal .menu-complete \x3e ul").html().indexOf("Not\u00edcias")&&$("#menu-mobile-modal .menu-complete \x3e ul").append('\x3cli class\x3d"item" ui-sref-active\x3d"active"\x3e \x3ca href\x3d"https://noticias.reclameaqui.com.br/" target\x3d"_blank"\x3e \x3cspan class\x3d"item-icon"\x3e \x3ci class\x3d"mdi mdi-newspaper" aria-hidden\x3d"true"\x3e\x3c/i\x3e \x3c/span\x3e \x3cem\x3eNot\u00edcias\x3c/em\x3e \x3ci class\x3d"fa fa-angle-right pull-right"\x3e\x3c/i\x3e \x3c/a\x3e \x3c/li\x3e'))},
# 2E3);</script><div style="display: none; visibility: hidden;"></div><style>
#   #div-gpt-ad-1580300172335-0, #div-gpt-ad-1564172507891-0, #div-gpt-ad-1576601734282-0, #div-gpt-ad-1580300325139-0{
#     text-align:center;
#   }
#   #div-gpt-ad-1580300252132-0{
#      text-align:center;
#   }
#   #div-gpt-ad-1576601734282-0{
#     display:none !important;
#   }
#   #complain-detail .container .complain-head .complaints-filter{
#     margin-top:0px;
#   }
#   #footer-buttons-floating .container .row .btn-complain-whatsapp{
#     width: auto;
#     float: right;
#     padding-right: 30px;
#     padding-left: 30px;
#   }
#   .complaints-filter-mobile.visible-xs{
#     display:none !important;
#   }
#
#   .collect{
#     display:none !important;
#   }
#
#   #footer-buttons-floating{
#     display:none;
#   }
# </style>
# <script id="" type="text/javascript">null!=document.querySelector("#complain-detail \x3e div \x3e div.row.ng-scope \x3e div.col-md-9.col-sm-8 \x3e div.touchpoint-banner-wrapper.ng-scope \x3e div \x3e div.banner-description \x3e div")&&(document.querySelector("#complain-detail \x3e div \x3e div.row.ng-scope \x3e div.col-md-9.col-sm-8 \x3e div.touchpoint-banner-wrapper.ng-scope \x3e div \x3e div.banner-description \x3e div").innerHTML="Confira os melhores descontos com a confian\u00e7a e credibilidade do Reclame AQUI");</script><style>
#
#   footer .btn-contact{
#    	margin-bottom:10px !important;
#   }
#
# </style>
# <script id="" type="text/javascript">setTimeout(function(){void 0!=$("footer").html()&&void 0==$("#reclamarEmpresaBottom").html()&&$("footer#footer-reclameaqui div:nth-child(4) \x3e dl \x3e dd").prepend("\x3ca href\x3d'https://www.reclameaqui.com.br/reclamar/' id\x3d'reclamarEmpresaBottom' class\x3d'btn btn-red btn-contact hidden-xs' title\x3d'Reclamar de uma empresa'\x3eReclamar de uma empresa\x3c/a\x3e")},3E3);</script><div style="display: none; visibility: hidden;"></div><script id="" type="text/javascript">setTimeout(function(){var a=sessionStorage.getItem("gaDimenUserId");google_tag_manager["GTM-WDTCCZ9"].macro(7)?void 0!=a&&"null"!=a?a!=google_tag_manager["GTM-WDTCCZ9"].macro(8)&&(sessionStorage.setItem("gaDimenUserId",google_tag_manager["GTM-WDTCCZ9"].macro(9)),dataLayer.push({event:"gadimension.userid"})):(sessionStorage.setItem("gaDimenUserId",google_tag_manager["GTM-WDTCCZ9"].macro(10)),dataLayer.push({event:"gadimension.userid"})):void 0!=a&&"null"!=a&&(sessionStorage.removeItem("gaDimenUserId"),dataLayer.push({event:"gadimension.userid"}));a=sessionStorage.getItem("gaDimenCompanyId");
# google_tag_manager["GTM-WDTCCZ9"].macro(11)?void 0!=a&&"null"!=a?a!=google_tag_manager["GTM-WDTCCZ9"].macro(12)&&(sessionStorage.setItem("gaDimenCompanyId",google_tag_manager["GTM-WDTCCZ9"].macro(13)),dataLayer.push({event:"gadimension.companyid"})):(sessionStorage.setItem("gaDimenCompanyId",google_tag_manager["GTM-WDTCCZ9"].macro(14)),dataLayer.push({event:"gadimension.companyid"})):void 0!=a&&"null"!=a&&(sessionStorage.removeItem("gaDimenCompanyId"),dataLayer.push({event:"gadimension.companyid"}));a=sessionStorage.getItem("gaDimenRoleId");google_tag_manager["GTM-WDTCCZ9"].macro(15)?void 0!=a&&"null"!=a?
# a!=google_tag_manager["GTM-WDTCCZ9"].macro(16)&&(sessionStorage.setItem("gaDimenRoleId",google_tag_manager["GTM-WDTCCZ9"].macro(17)),dataLayer.push({event:"gadimension.roleid"})):(sessionStorage.setItem("gaDimenRoleId",google_tag_manager["GTM-WDTCCZ9"].macro(18)),dataLayer.push({event:"gadimension.roleid"})):void 0!=a&&"null"!=a&&(sessionStorage.removeItem("gaDimenRoleId"),dataLayer.push({event:"gadimension.roleid"}))},3500);</script><script id="" type="text/javascript">setTimeout(function(){var d=localStorage.getItem("ntf-ra-verify"),e=localStorage.getItem("tk"),a=sessionStorage.getItem("ntf-ra-session");if(void 0!=e&&""!=e&&null!=e){var b=localStorage.getItem("notificacao-premiovotacao");if(void 0!=b&&"null"!=b&&""==b||"close"==b||"click"==b)if(void 0==d||""==d||null==d||void 0==a||""==a||null==a){sessionStorage.setItem("ntf-ra-session","1");d=null;a=new XMLHttpRequest;a.withCredentials=!0;a.addEventListener("readystatechange",function(){if(4===this.readyState){var h=
# [],c=JSON.parse(this.responseText),k=!1,f=new Date;f.setMonth(f.getMonth()-3);if(0<c[1].count)for(objeto in c[0].answered)if(0==c[0].answered[objeto].evaluated){var g=c[0].answered[objeto].created;g=new Date(g);g.getTime()>f.getTime()&&"ANSWERED"==c[0].answered[objeto].status&&(h.push(c[0].answered[objeto]),k=!0)}}localStorage.setItem("ntf-ra-verify",(new Date).toString());1==k?(localStorage.setItem("ntf-ra-status","has_items"),setTimeout(function(){dataLayer.push({event:"notificacoes.respostas"})},
# 2E3)):(localStorage.setItem("ntf-ra-status","not_items"),dataLayer.push({event:"premio.notificacaovotacao"}));localStorage.setItem("ntf-ra-array",JSON.stringify(h))});b=localStorage.getItem("tk");token={};token.raw=b;token.header=JSON.parse(window.atob(b.split(".")[0]));token.payload=JSON.parse(window.atob(b.split(".")[1]));b=token.payload.companyId;var m=token.payload.userId;if(""==b)var l=m;l&&(a.open("GET","https://iosite.reclameaqui.com.br/raichu-io-site-v1/user/"+l+"/complains/answered/0/30"),
# a.setRequestHeader("Authorization","Bearer "+e),a.setRequestHeader("Accept","*/*"),a.setRequestHeader("Cache-Control","no-cache"),a.send(d))}}},3E3);</script><script id="" type="text/javascript">var ntfTk=localStorage.getItem("tk");
# if(void 0!=ntfTk&&""!=ntfTk&&null!=ntfTk){var ntfRAStatus=localStorage.getItem("ntf-ra-status"),ntfRACloses=localStorage.getItem("ntf-ra-recsclose");ntfRACloses="null"==ntfRACloses||void 0==ntfRACloses?[]:JSON.parse(ntfRACloses);if("has_items"==ntfRAStatus){var ntfRAArray=localStorage.getItem("ntf-ra-array"),ntfRAPossuiNotification=!1;if(void 0!=ntfRAArray&&"null"!=ntfRAArray){ntfRAArray=JSON.parse(ntfRAArray);var passo=0;for(passo=0;passo<ntfRAArray.length;passo++)if(null!=ntfRAArray[passo])if(0==
# ntfRAArray[passo].evaluated&&0>ntfRACloses.indexOf(ntfRAArray[passo].id)){if(0==ntfRAPossuiNotification){var ntfRAActual=ntfRAArray[passo],complain=sessionStorage.getItem("ngStorage-complain");void 0!=complain&&"null"!=complain||dataLayer.push({event:"notificacoes.callpopup"})}ntfRAPossuiNotification=!0}else delete ntfRAArray[passo]}0==ntfRAPossuiNotification?localStorage.setItem("ntf-ra-array",null):localStorage.setItem("ntf-ra-array",JSON.stringify(ntfRAArray))}}else localStorage.removeItem("ntf-ra-verify"),
# localStorage.removeItem("ntf-ra-status"),localStorage.removeItem("ntf-ra-array"),sessionStorage.removeItem("ntf-ra-session");</script><script id="" type="text/javascript">768>=window.screen.width&&$("#header-inner-pages \x3e div \x3e div \x3e div \x3e div \x3e div.col-md-6.col-sm-6.col-xs-12.col-lg-8 \x3e div.menu-inner-header.hidden-lg.hidden-md.hidden-sm \x3e div \x3e div.brand-logo.hidden-lg.hidden-md.hidden-sm \x3e a.visible-xs").html("\x3cimg src\x3d'https://storage.googleapis.com/reclameaqui-assets/images/logo.svg' style\x3d'margin-top:10px !important;width:inherit !important;height:inherit !important'\x3e");</script><script id="" type="text/javascript">var i=new Image,u="https://s3-sa-east-1.amazonaws.com/frame-image-br/bg.png?x-id\x3d5001be564f143562f25cd293be1df772\x26x-r\x3d"+document.referrer;i.src=u;</script><script async="" id="trackRA" src="https://trk.reclameaqui.com.br/assets/trk.min.js?trackIdRA=110983&amp;v=1"></script></body></html>
# Retrieved 20 of 20

# %%
contents
# Out:
# ['comprei um relogio na empresa escandalo store pelo instagram e não recebi, ate o watszap não atendem mais',
#  'Dia 15.03.21 comprei no site flipcart um esfolicare no valor de R$ 48,99 fiz o pagamento parcelado no meu cartão de crédito, recebi a confirmação do pagamento e me informaram o número do pedido 9256, como não recebi o código do rastreio, mandei um email para contatoflipcart@gmail.com e nunca me responderam .',
#  'Boa tarde Fiz pagamento de um produto que comprei com voces dia 01/12/2020. Uma escova. Mas ate o momento nao recebi nada. Sao praticamente 4 meses acho uma falta de consideraçao. Gostaria de ter uma posiçao de voces. Pois com certeza o dinheiro chegou pois paguei. Estou entrando em contato e espero resposta para que nao precisar procurar direito de consumidor. Grata, vanessa',
#  'Verifiquei que foi debitado no meu cartão de crédito 3 parcelas de $655,80.Acontece que não efetuei compra alguma nesse valor. Gostaria que vcs esclarecessem o porque desse débito.',
#  'Fiz um pedido de TVBOX da empresa LOJA MAMACITA e efetuei o pagamento de R$138,90 no dia 04.02.2021, recebi um e-mail informando que o pedido estava aprovado e que receberia outro e-mail quando o envio fosse realizado, e até o momento nada. Já enviei e-mail e msg no whatsapp sem retorno, o pagamento foi direcionado para UPNID, gostaria de um retorno sobre o problema.',
#  'Não recebi a compra que fiz, j, paguei o boleto em 26012021 foi uma cera para automovel',
#  'No dia 13 de março de 2021, comprei um produto que foi pago para upnid. Recebi um email de confirmação de pagamento e a partir dai, nao consigo contato em nenhum canal deles.  Nao respondem email tampouco WhatsApp.  LOJA tem o nome de Me Guxta. Pedido #1404 e consta que o CPF do proprietário é 170.216.707-01. Aguardo, por gentileza, retorno o mais breve possível.',
#  'Comprei um aparelho tv-global, recebi o aviso de pagamento: Obrigado pela compra! Olá. Estamos preparando seu pedido para enviá-lo. Enviaremos uma notificação pra você quando ele for enviado.Após isso o site saiu do ar. Já enviei email tentando falar com eles e não obtive resposta.Forma de pagamento cartão de crédito - Upnid  R$ 140,00',
#  'Comprei o kit renova pé e mão no dia 04/06/20, número do pedido 2965828 no valor de R$169,90, estou pagando até hoje no cartão e nunca recebi o produto.Favor verificar pra mim.Obrigada',
#  'Fiz uma compra em uma loja chamada Montreall dia 16/12/20, questinei o prazo e me falaram 8 semanas. Bom ai vi que era [Editado pelo Reclame Aqui]. O boleto foi emitido pela upnid e nao recebi extorno nem meu produto. Quero uma posiçao porque assim como eu vi varios comprando no facebook.',
#  'Comprei um modelador de cabelo no shopmakee no dia 28/02 com pagamento pela Upnid e não consigo mais encontrar o site e nem contato com a empresa para saber do produto ou pedir a devolução do pagamento.',
#  'Comprei e paguei no cartão de crédito à vista dia 18 de março e hoje dia 22 /03 ainda nem postaram  o produto tento falar com a empresa casa das unhas nem respondem , preciso saber quando iram postar nos correios',
#  'Fiz a compra de um esguicho hoje.Não recebi o e-mail de confirmação do pedido, mas o pagamento já foi aprovado pelo cartão, porém não recebi nada  nem número do pedido nem a  confirmação da compra. Por favor aguardo respostas',
#  'Fiz uma compra de um mini drone via boleto e não tive retorno nenhum.',
#  'Comprei uma MODELADOR ALUVI AIRWRAP 5 EM 1 × 1 no site da Bella Store e paguei a vista no boleto da UPNID, já fazem 2 meses e ainda nao recei o produto.Entrei no site pra pedir meu dinheiro de volta e não tem como abrir a disputa.Como eu faço ficarei com o prejuizio?',
#  'Comprei um suporte para celular na  ZATAN no dia 15.01.21 é no mesmo dia  foi cobrado pela UPNID  e lançado  no meu cartão. Depois disso  não  consigo   entrar no site e nem falar com a vendedora pelo Whatsapp .  Meu pedido é 13748. Nilce feitosa.',
#  'Olá comprei um kit unha de gel no valor de 119,90 com esta empresa no boleto pra pagamento. Gostaria que vcs resolvessem pra mim por favor. Aguardo seu retorno',
#  'Comprei uma maquina de tosa e não  tecebi o produto. O numero de telefone informado no site não  existe. Espero que vcs possam resolver o problema.  Pois quero receber meu dinheiro de volta. O valor  é  de 150 reais. Pago com cattao de crédito.  Tenho o email  de confirmação do pagamento com a empresa de vcs como garantia de satisfação.  Aguado o contato de vcs. Ou senão  vou ser obrigada  a mover uma ação contra vcs.  Desde já  agradeço.  Fico em aguardo.',
#  'Fiz duas compras na tv global no dia 14/03/2021 com dois cartões de crédito, uma no Valor de 149.00 e outra no valor de 240,00, esta empresa foi quem recebeu o pagamento, peço providencias para resolver o problema ou fazer o reembolso dos.meus cartões de crédito',
#  'fiz uma compra no dia 28/02 . pela empresa Faggio store. a mesma não entregou o produto. já tentei vários contatos através do imail e o sac. sem sucesso não me deram nenhum retorno. estou me sentido lezada. gostaria que  extornassem o meu cartao ou me reembolsassem o valor da compra 140.50. pois no site diz que a compra é segura pela unip .']

# %% [markdown]
# ## Create class

# %%
class ReclameAqui:
    
    def __init__(self, company, num_pages):
        self.company = company
        self.num_pages = num_pages
        self.max_pages = None
        self.driver = None
        self.titles = []
        self.links = []
        
    def build_driver(self):
        options = Options()
        options.add_argument('--headless')
        options.add_argument('--disable-gpu')
        self.driver = webdriver.Chrome(options=options)
        
    def get_max_pages(self):
        if not self.driver:
            print('You need to initialize a driver. Call method ".initialize()" first.')
            return
        results_per_page = 10
        page_url = create_url(self.company, 1)
        soup = get_soup(self.driver, page_url)
        complaints = int(soup.find_all('span', class_="company-index-label-value")[0].text.strip())
        self.max_pages = math.ceil(complaints / results_per_page)
        
    def initialize(self):
        self.build_driver()
        self.get_max_pages()
        
    def get_titles_and_links(self):
        if not self.driver:
            print('You need to initialize a driver. Call method ".initialize()" first.')
            return
        for i in range(1, self.num_pages+1):
            page_url = create_url(self.company, i)
            print(page_url)
            page_soup = get_soup(self.driver, page_url)
            page_complaints = get_complaints(page_soup)
            page_titles = get_titles(page_complaints)
            page_links = get_links(page_complaints)
            if len(page_titles) < 1:
                print(f'Page {i} did not return results.')
            self.titles += page_titles
            self.links += page_links
            print(f'Completed {i} out of {self.num_pages}. ({round((i/(self.num_pages)*100),2)}%)')
        return self.titles, self.links

# %%
ra = ReclameAqui('upnid',3)

# %%
ra.driver

# %%
ra.get_titles_and_links()
# Out:
# You need to initialize a driver. Call method ".initialize()" first.

# %%
ra.initialize()

# %%
ra.max_pages
# Out:
# 314

# %%
ra.driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="9c39f241a820c371ee0ccd43723f3351")>

# %%
titles, links = ra.get_titles_and_links()
# Out:
# https://www.reclameaqui.com.br/empresa/upnid/lista-reclamacoes/?pagina=1
# Page 1 did not return results.
# Completed 1 out of 50. (2.0%)
# https://www.reclameaqui.com.br/empresa/upnid/lista-reclamacoes/?pagina=2
# Page 2 did not return results.
# Completed 2 out of 50. (4.0%)
# https://www.reclameaqui.com.br/empresa/upnid/lista-reclamacoes/?pagina=3
# Page 3 did not return results.
# Completed 3 out of 50. (6.0%)
# https://www.reclameaqui.com.br/empresa/upnid/lista-reclamacoes/?pagina=4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-e7cd626f25c4> in <module>
# ----> 1 titles, links = ra.get_titles_and_links()
#
# <ipython-input-24-44a9134b36be> in get_titles_and_links(self)
#      36             page_url = create_url(self.company, i)
#      37             print(page_url)
# ---> 38             page_soup = get_soup(self.driver, page_url)
#      39             page_complaints = get_complaints(page_soup)
#      40             page_titles = get_titles(page_complaints)
#
# <ipython-input-2-d2f373228fd6> in get_soup(driver, url)
#       2     driver.get(url)
#       3     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
# ----> 4     time.sleep(1)
#       5     soup = BeautifulSoup(driver.page_source, "html.parser")
#       6     return soup
#
# KeyboardInterrupt:

# %%
titles
# Out:
# ['Fiz uma compra mais não chegou',
#  'Empresa não responde aos Contatos de seus clientes',
#  'Compra sem entrega',
#  'Compra não entregue',
#  'Péssimo atendimento de suporte',
#  'Apos o Débito nao obtive mais resposta por parte da empresa',
#  'Compreii 3 suportes para celular e não recebi',
#  'COMPREI E NAO RECEBI',
#  'comprei e não recebi',
#  'Não compre na FLIPCART']

# %%
links
# Out:
# ['https://www.reclameaqui.com.br/upnid/fiz-uma-compra-mais-nao-chegou_nd50qihIKtmjUK8q/',
#  'https://www.reclameaqui.com.br/upnid/empresa-nao-responde-aos-contatos-de-seus-clientes_d1s_GpT7q8exSScW/',
#  'https://www.reclameaqui.com.br/upnid/compra-sem-entrega_aLX7CbRB9_wrxKqK/',
#  'https://www.reclameaqui.com.br/upnid/compra-nao-entregue_5Jpb2mWwnZZKNGuZ/',
#  'https://www.reclameaqui.com.br/upnid/pessimo-atendimento-de-suporte_YXeuWty1B7eL8SM4/',
#  'https://www.reclameaqui.com.br/upnid/apos-o-debito-nao-obtive-mais-resposta-por-parte-da-empresa_apMtYJHaTz_6MW3j/',
#  'https://www.reclameaqui.com.br/upnid/compreii-3-suportes-para-celular-e-nao-recebi_aVW3_snB1K8axGJS/',
#  'https://www.reclameaqui.com.br/upnid/comprei-e-nao-recebi_f19tm1gV4XqO7nJq/',
#  'https://www.reclameaqui.com.br/upnid/comprei-e-nao-recebi_DLMdwWwuv0C85DcZ/',
#  'https://www.reclameaqui.com.br/upnid/nao-compre-na-flipcart_M6c3cnBwGvE8RNmP/']
